# %%
import pandas as pd

# %%
destination1 = "XLS/2017/2017_manhattan.xls"
man_2017 = pd.read_excel(destination1, index_col=0, skiprows=4)
man_2017.head()
# Out:
#           NEIGHBORHOOD\n                    BUILDING CLASS CATEGORY\n  \
# BOROUGH\n
# 1          ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 1          ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 1          ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 1          ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 1          ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
#
#           TAX CLASS AS OF FINAL ROLL 17/18  BLOCK\n  LOT\n EASE-MENT\n  \
# BOROUGH\n
# 1                                        2      375     28
# 1                                        2      385     36
# 1                                       2A      392      5
# 1                                       2A      392      6
# 1                                        2      400     61
#
#           BUILDING CLASS AS OF FINAL ROLL 17/18              ADDRESS\n  \
# BOROUGH\n
# 1                                            C4    738 EAST 6TH STREET
# ...

# %%
man_2017.dtypes
# Out:
# NEIGHBORHOOD\n                                   object
# BUILDING CLASS CATEGORY\n                        object
# TAX CLASS AS OF FINAL ROLL 17/18                 object
# BLOCK\n                                           int64
# LOT\n                                             int64
# EASE-MENT\n                                      object
# BUILDING CLASS AS OF FINAL ROLL 17/18            object
# ADDRESS\n                                        object
# APARTMENT NUMBER\n                               object
# ZIP CODE\n                                        int64
# RESIDENTIAL UNITS\n                               int64
# COMMERCIAL UNITS\n                                int64
# TOTAL UNITS\n                                     int64
# LAND SQUARE FEET\n                                int64
# GROSS SQUARE FEET\n                               int64
# YEAR BUILT\n                                      int64
# TAX CLASS AT TIME OF SALE\n                       int64
# ...

# %%
destination2 = "XLS/2017/2017_bronx.xls"
bronx_2017 = pd.read_excel(destination2, index_col=0, skiprows=4)
bronx_2017.head()
# Out:
#           NEIGHBORHOOD\n                    BUILDING CLASS CATEGORY\n  \
# BOROUGH\n
# 2               BATHGATE  01 ONE FAMILY DWELLINGS
# 2               BATHGATE  01 ONE FAMILY DWELLINGS
# 2               BATHGATE  01 ONE FAMILY DWELLINGS
# 2               BATHGATE  01 ONE FAMILY DWELLINGS
# 2               BATHGATE  01 ONE FAMILY DWELLINGS
#
#           TAX CLASS AS OF FINAL ROLL 17/18  BLOCK\n  LOT\n EASE-MENT\n  \
# BOROUGH\n
# 2                                        1     3028     25
# 2                                        1     3030     55
# 2                                        1     3030     56
# 2                                        1     3030     56
# 2                                        1     3030     65
#
#           BUILDING CLASS AS OF FINAL ROLL 17/18              ADDRESS\n  \
# BOROUGH\n
# 2                                            A5    412 EAST 179 STREET
# 2                                            A5  410 EAST 182ND STREET
# ...

# %%
bronx_2017.dtypes
# Out:
# NEIGHBORHOOD\n                                   object
# BUILDING CLASS CATEGORY\n                        object
# TAX CLASS AS OF FINAL ROLL 17/18                 object
# BLOCK\n                                           int64
# LOT\n                                             int64
# EASE-MENT\n                                      object
# BUILDING CLASS AS OF FINAL ROLL 17/18            object
# ADDRESS\n                                        object
# APARTMENT NUMBER\n                               object
# ZIP CODE\n                                        int64
# RESIDENTIAL UNITS\n                               int64
# COMMERCIAL UNITS\n                                int64
# TOTAL UNITS\n                                     int64
# LAND SQUARE FEET\n                                int64
# GROSS SQUARE FEET\n                               int64
# YEAR BUILT\n                                      int64
# TAX CLASS AT TIME OF SALE\n                       int64
# ...

# %%
destination3 = "XLS/2017/2017_brooklyn.xls"
brooklyn_2017 = pd.read_excel(destination3, index_col=0, skiprows=4)
brooklyn_2017.head()
# Out:
#           NEIGHBORHOOD\n                    BUILDING CLASS CATEGORY\n  \
# BOROUGH\n
# 3             BATH BEACH  01 ONE FAMILY DWELLINGS
# 3             BATH BEACH  01 ONE FAMILY DWELLINGS
# 3             BATH BEACH  01 ONE FAMILY DWELLINGS
# 3             BATH BEACH  01 ONE FAMILY DWELLINGS
# 3             BATH BEACH  01 ONE FAMILY DWELLINGS
#
#           TAX CLASS AS OF FINAL ROLL 17/18  BLOCK\n  LOT\n EASE-MENT\n  \
# BOROUGH\n
# 3                                        1     6360     55
# 3                                        1     6360    157
# 3                                        1     6361     20
# 3                                        1     6367     42
# 3                                        1     6393     16
#
#           BUILDING CLASS AS OF FINAL ROLL 17/18             ADDRESS\n  \
# BOROUGH\n
# 3                                            A5    28 BAY 10TH STREET
# 3                                            A5  36 BAY 10TH   STREET
# ...

# %%
brooklyn_2017.dtypes
# Out:
# NEIGHBORHOOD\n                                   object
# BUILDING CLASS CATEGORY\n                        object
# TAX CLASS AS OF FINAL ROLL 17/18                 object
# BLOCK\n                                           int64
# LOT\n                                             int64
# EASE-MENT\n                                      object
# BUILDING CLASS AS OF FINAL ROLL 17/18            object
# ADDRESS\n                                        object
# APARTMENT NUMBER\n                               object
# ZIP CODE\n                                        int64
# RESIDENTIAL UNITS\n                               int64
# COMMERCIAL UNITS\n                                int64
# TOTAL UNITS\n                                     int64
# LAND SQUARE FEET\n                                int64
# GROSS SQUARE FEET\n                               int64
# YEAR BUILT\n                                      int64
# TAX CLASS AT TIME OF SALE\n                       int64
# ...

# %%
destination4 = "XLS/2017/2017_queens.xls"
queens_2017 = pd.read_excel(destination4, index_col=0, skiprows=4)
queens_2017.head()
# Out:
#                NEIGHBORHOOD\n                    BUILDING CLASS CATEGORY\n  \
# BOROUGH\n
# 4          AIRPORT LA GUARDIA  01 ONE FAMILY DWELLINGS
# 4          AIRPORT LA GUARDIA  01 ONE FAMILY DWELLINGS
# 4          AIRPORT LA GUARDIA  01 ONE FAMILY DWELLINGS
# 4          AIRPORT LA GUARDIA  01 ONE FAMILY DWELLINGS
# 4          AIRPORT LA GUARDIA  01 ONE FAMILY DWELLINGS
#
#           TAX CLASS AS OF FINAL ROLL 17/18  BLOCK\n  LOT\n EASE-MENT\n  \
# BOROUGH\n
# 4                                        1      976     10
# 4                                        1      976     10
# 4                                        1      976     11
# 4                                        1      976     11
# 4                                        1      976     15
#
#           BUILDING CLASS AS OF FINAL ROLL 17/18            ADDRESS\n  \
# BOROUGH\n
# 4                                            A5    21-10 81ST STREET
# ...

# %%
queens_2017.dtypes
# Out:
# NEIGHBORHOOD\n                                   object
# BUILDING CLASS CATEGORY\n                        object
# TAX CLASS AS OF FINAL ROLL 17/18                 object
# BLOCK\n                                           int64
# LOT\n                                             int64
# EASE-MENT\n                                      object
# BUILDING CLASS AS OF FINAL ROLL 17/18            object
# ADDRESS\n                                        object
# APARTMENT NUMBER\n                               object
# ZIP CODE\n                                        int64
# RESIDENTIAL UNITS\n                               int64
# COMMERCIAL UNITS\n                                int64
# TOTAL UNITS\n                                     int64
# LAND SQUARE FEET\n                                int64
# GROSS SQUARE FEET\n                               int64
# YEAR BUILT\n                                      int64
# TAX CLASS AT TIME OF SALE\n                       int64
# ...

# %%
destination5 = "XLS/2017/2017_statenisland.xls"
statenisland_2017 = pd.read_excel(destination5, index_col=0, skiprows=4)
statenisland_2017.head()
# Out:
#           NEIGHBORHOOD\n                    BUILDING CLASS CATEGORY\n  \
# BOROUGH\n
# 5               ANNADALE  01 ONE FAMILY DWELLINGS
# 5               ANNADALE  01 ONE FAMILY DWELLINGS
# 5               ANNADALE  01 ONE FAMILY DWELLINGS
# 5               ANNADALE  01 ONE FAMILY DWELLINGS
# 5               ANNADALE  01 ONE FAMILY DWELLINGS
#
#           TAX CLASS AS OF FINAL ROLL 17/18  BLOCK\n  LOT\n EASE-MENT\n  \
# BOROUGH\n
# 5                                        1     5395     19
# 5                                        1     5407     10
# 5                                        1     5407     39
# 5                                        1     5426     32
# 5                                        1     6205     15
#
#           BUILDING CLASS AS OF FINAL ROLL 17/18            ADDRESS\n  \
# BOROUGH\n
# 5                                            A1       4 EDWIN STREET
# 5                                            A2   112 ELMBANK STREET
# ...

# %%
statenisland_2017.dtypes
# Out:
# NEIGHBORHOOD\n                                   object
# BUILDING CLASS CATEGORY\n                        object
# TAX CLASS AS OF FINAL ROLL 17/18                 object
# BLOCK\n                                           int64
# LOT\n                                             int64
# EASE-MENT\n                                      object
# BUILDING CLASS AS OF FINAL ROLL 17/18            object
# ADDRESS\n                                        object
# APARTMENT NUMBER\n                               object
# ZIP CODE\n                                        int64
# RESIDENTIAL UNITS\n                               int64
# COMMERCIAL UNITS\n                                int64
# TOTAL UNITS\n                                     int64
# LAND SQUARE FEET\n                                int64
# GROSS SQUARE FEET\n                               int64
# YEAR BUILT\n                                      int64
# TAX CLASS AT TIME OF SALE\n                       int64
# ...

# %%
nyc_rolling_2017 = pd.concat([man_2017, bronx_2017, brooklyn_2017, queens_2017, statenisland_2017])
nyc_rolling_2017.head()
# nyc_rolling_2017.dtypes
# Out:
#           NEIGHBORHOOD\n                    BUILDING CLASS CATEGORY\n  \
# BOROUGH\n
# 1          ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 1          ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 1          ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 1          ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
# 1          ALPHABET CITY  07 RENTALS - WALKUP APARTMENTS
#
#           TAX CLASS AS OF FINAL ROLL 17/18  BLOCK\n  LOT\n EASE-MENT\n  \
# BOROUGH\n
# 1                                        2      375     28
# 1                                        2      385     36
# 1                                       2A      392      5
# 1                                       2A      392      6
# 1                                        2      400     61
#
#           BUILDING CLASS AS OF FINAL ROLL 17/18              ADDRESS\n  \
# BOROUGH\n
# 1                                            C4    738 EAST 6TH STREET
# ...
