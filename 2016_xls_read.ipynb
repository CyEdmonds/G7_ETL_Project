# %%
import pandas as pd

# %%
destination1 = "XLS/2016/2016_manhattan.xls"
man_2016 = pd.read_excel(destination1, index_col=0, skiprows=4)
man_2016.head()
# Out:
#                       NEIGHBORHOOD\n  \
# BOROUGH\n
# 1          ALPHABET CITY
# 1          ALPHABET CITY
# 1          ALPHABET CITY
# 1          ALPHABET CITY
# 1          ALPHABET CITY
#
#                               BUILDING CLASS CATEGORY\n  \
# BOROUGH\n
# 1          03  THREE FAMILY DWELLINGS
# 1          07  RENTALS - WALKUP APARTMENTS
# 1          07  RENTALS - WALKUP APARTMENTS
# 1          07  RENTALS - WALKUP APARTMENTS
# 1          07  RENTALS - WALKUP APARTMENTS
#
#           TAX CLASS AT PRESENT\n  BLOCK\n  LOT\n EASE-MENT\n  \
# BOROUGH\n
# 1                              1      376     24
# 1                              2      385      2
# 1                             2B      389     53
# 1                              2      399     26
# 1                              2      399     39
#
#           BUILDING CLASS AT PRESENT\n  \
# BOROUGH\n
# 1                                  C0
# 1                                  C7
# 1                                  C1
# ...

# %%
man_2016.dtypes
# Out:
# NEIGHBORHOOD\n                              object
# BUILDING CLASS CATEGORY\n                   object
# TAX CLASS AT PRESENT\n                      object
# BLOCK\n                                      int64
# LOT\n                                        int64
# EASE-MENT\n                                 object
# BUILDING CLASS AT PRESENT\n                 object
# ADDRESS\n                                   object
# APARTMENT NUMBER\n                          object
# ZIP CODE\n                                   int64
# RESIDENTIAL UNITS\n                          int64
# COMMERCIAL UNITS\n                           int64
# TOTAL UNITS\n                                int64
# LAND SQUARE FEET\n                           int64
# GROSS SQUARE FEET\n                          int64
# YEAR BUILT\n                                 int64
# TAX CLASS AT TIME OF SALE\n                  int64
# BUILDING CLASS AT TIME OF SALE\n            object
# ...

# %%
destination2 = "XLS/2016/2016_bronx.xls"
bronx_2016 = pd.read_excel(destination2, index_col=0, skiprows=4)
bronx_2016.head()
# Out:
#                       NEIGHBORHOOD\n  \
# BOROUGH\n
# 2          BATHGATE
# 2          BATHGATE
# 2          BATHGATE
# 2          BATHGATE
# 2          BATHGATE
#
#                               BUILDING CLASS CATEGORY\n  \
# BOROUGH\n
# 2          01  ONE FAMILY DWELLINGS
# 2          01  ONE FAMILY DWELLINGS
# 2          01  ONE FAMILY DWELLINGS
# 2          01  ONE FAMILY DWELLINGS
# 2          01  ONE FAMILY DWELLINGS
#
#           TAX CLASS AT PRESENT\n  BLOCK\n  LOT\n EASE-MENT\n  \
# BOROUGH\n
# 2                              1     3037    101
# 2                              1     3043     55
# 2                              1     3046     52
# 2                              1     3046     52
# 2                              1     3048     27
#
#           BUILDING CLASS AT PRESENT\n  \
# BOROUGH\n
# 2                                  S0
# 2                                  A1
# 2                                  A1
# 2                                  A1
# ...

# %%
bronx_2016.dtypes
# Out:
# NEIGHBORHOOD\n                              object
# BUILDING CLASS CATEGORY\n                   object
# TAX CLASS AT PRESENT\n                      object
# BLOCK\n                                      int64
# LOT\n                                        int64
# EASE-MENT\n                                 object
# BUILDING CLASS AT PRESENT\n                 object
# ADDRESS\n                                   object
# APARTMENT NUMBER\n                          object
# ZIP CODE\n                                   int64
# RESIDENTIAL UNITS\n                          int64
# COMMERCIAL UNITS\n                           int64
# TOTAL UNITS\n                                int64
# LAND SQUARE FEET\n                           int64
# GROSS SQUARE FEET\n                          int64
# YEAR BUILT\n                                 int64
# TAX CLASS AT TIME OF SALE\n                  int64
# BUILDING CLASS AT TIME OF SALE\n            object
# ...

# %%
destination3 = "XLS/2016/2016_brooklyn.xls"
brooklyn_2016 = pd.read_excel(destination3, index_col=0, skiprows=4)
brooklyn_2016.head()
# Out:
#                       NEIGHBORHOOD\n  \
# BOROUGH\n
# 3          BATH BEACH
# 3          BATH BEACH
# 3          BATH BEACH
# 3          BATH BEACH
# 3          BATH BEACH
#
#                               BUILDING CLASS CATEGORY\n  \
# BOROUGH\n
# 3          01  ONE FAMILY DWELLINGS
# 3          01  ONE FAMILY DWELLINGS
# 3          01  ONE FAMILY DWELLINGS
# 3          01  ONE FAMILY DWELLINGS
# 3          01  ONE FAMILY DWELLINGS
#
#           TAX CLASS AT PRESENT\n  BLOCK\n  LOT\n EASE-MENT\n  \
# BOROUGH\n
# 3                              1     6360     13
# 3                              1     6361     11
# 3                              1     6364      2
# 3                              1     6364     72
# 3                              1     6371     79
#
#           BUILDING CLASS AT PRESENT\n  \
# BOROUGH\n
# 3                                  A5
# 3                                  A5
# 3                                  A5
# 3                                  A5
# ...

# %%
brooklyn_2016.dtypes
# Out:
# NEIGHBORHOOD\n                              object
# BUILDING CLASS CATEGORY\n                   object
# TAX CLASS AT PRESENT\n                      object
# BLOCK\n                                      int64
# LOT\n                                        int64
# EASE-MENT\n                                 object
# BUILDING CLASS AT PRESENT\n                 object
# ADDRESS\n                                   object
# APARTMENT NUMBER\n                          object
# ZIP CODE\n                                   int64
# RESIDENTIAL UNITS\n                          int64
# COMMERCIAL UNITS\n                           int64
# TOTAL UNITS\n                                int64
# LAND SQUARE FEET\n                           int64
# GROSS SQUARE FEET\n                          int64
# YEAR BUILT\n                                 int64
# TAX CLASS AT TIME OF SALE\n                  int64
# BUILDING CLASS AT TIME OF SALE\n            object
# ...

# %%
destination4 = "XLS/2016/2016_queens.xls"
queens_2016 = pd.read_excel(destination4, index_col=0, skiprows=4)
queens_2016.head()
# Out:
#                       NEIGHBORHOOD\n  \
# BOROUGH\n
# 4          AIRPORT JFK
# 4          AIRPORT LA GUARDIA
# 4          AIRPORT LA GUARDIA
# 4          AIRPORT LA GUARDIA
# 4          AIRPORT LA GUARDIA
#
#                               BUILDING CLASS CATEGORY\n  \
# BOROUGH\n
# 4          31  COMMERCIAL VACANT LAND
# 4          01  ONE FAMILY DWELLINGS
# 4          01  ONE FAMILY DWELLINGS
# 4          02  TWO FAMILY DWELLINGS
# 4          03  THREE FAMILY DWELLINGS
#
#           TAX CLASS AT PRESENT\n  BLOCK\n  LOT\n EASE-MENT\n  \
# BOROUGH\n
# 4                              4    14260     70
# 4                              1      976     61
# 4                              1      976     63
# 4                              1      976     70
# 4                              1      949     15
#
#           BUILDING CLASS AT PRESENT\n  \
# BOROUGH\n
# 4                                  V1
# 4                                  A5
# 4                                  A5
# ...

# %%
queens_2016.dtypes
# Out:
# NEIGHBORHOOD\n                              object
# BUILDING CLASS CATEGORY\n                   object
# TAX CLASS AT PRESENT\n                      object
# BLOCK\n                                      int64
# LOT\n                                        int64
# EASE-MENT\n                                 object
# BUILDING CLASS AT PRESENT\n                 object
# ADDRESS\n                                   object
# APARTMENT NUMBER\n                          object
# ZIP CODE\n                                   int64
# RESIDENTIAL UNITS\n                          int64
# COMMERCIAL UNITS\n                           int64
# TOTAL UNITS\n                                int64
# LAND SQUARE FEET\n                           int64
# GROSS SQUARE FEET\n                          int64
# YEAR BUILT\n                                 int64
# TAX CLASS AT TIME OF SALE\n                  int64
# BUILDING CLASS AT TIME OF SALE\n            object
# ...

# %%
destination5 = "XLS/2016/2016_statenisland.xls"
statenisland_2016 = pd.read_excel(destination5, index_col=0, skiprows=4)
statenisland_2016.head()
# Out:
#                       NEIGHBORHOOD\n  \
# BOROUGH\n
# 5          ANNADALE
# 5          ANNADALE
# 5          ANNADALE
# 5          ANNADALE
# 5          ANNADALE
#
#                               BUILDING CLASS CATEGORY\n  \
# BOROUGH\n
# 5          01  ONE FAMILY DWELLINGS
# 5          01  ONE FAMILY DWELLINGS
# 5          01  ONE FAMILY DWELLINGS
# 5          01  ONE FAMILY DWELLINGS
# 5          01  ONE FAMILY DWELLINGS
#
#           TAX CLASS AT PRESENT\n  BLOCK\n  LOT\n EASE-MENT\n  \
# BOROUGH\n
# 5                              1     5391      9
# 5                              1     5391     30
# 5                              1     5395     15
# 5                              1     5397     60
# 5                              1     5399     26
#
#           BUILDING CLASS AT PRESENT\n  \
# BOROUGH\n
# 5                                  A5
# 5                                  A1
# 5                                  A1
# 5                                  A1
# ...

# %%
statenisland_2016.dtypes
# Out:
# NEIGHBORHOOD\n                              object
# BUILDING CLASS CATEGORY\n                   object
# TAX CLASS AT PRESENT\n                      object
# BLOCK\n                                      int64
# LOT\n                                        int64
# EASE-MENT\n                                 object
# BUILDING CLASS AT PRESENT\n                 object
# ADDRESS\n                                   object
# APARTMENT NUMBER\n                          object
# ZIP CODE\n                                   int64
# RESIDENTIAL UNITS\n                          int64
# COMMERCIAL UNITS\n                           int64
# TOTAL UNITS\n                                int64
# LAND SQUARE FEET\n                           int64
# GROSS SQUARE FEET\n                          int64
# YEAR BUILT\n                                 int64
# TAX CLASS AT TIME OF SALE\n                  int64
# BUILDING CLASS AT TIME OF SALE\n            object
# ...

# %%
nyc_rolling_2016 = pd.concat([man_2016, bronx_2016, brooklyn_2016, queens_2016, statenisland_2016])
# nyc_rolling_2016.head()
# nyc_rolling_2016.dtypes
# Out:
# NEIGHBORHOOD\n                              object
# BUILDING CLASS CATEGORY\n                   object
# TAX CLASS AT PRESENT\n                      object
# BLOCK\n                                      int64
# LOT\n                                        int64
# EASE-MENT\n                                 object
# BUILDING CLASS AT PRESENT\n                 object
# ADDRESS\n                                   object
# APARTMENT NUMBER\n                          object
# ZIP CODE\n                                   int64
# RESIDENTIAL UNITS\n                          int64
# COMMERCIAL UNITS\n                           int64
# TOTAL UNITS\n                                int64
# LAND SQUARE FEET\n                           int64
# GROSS SQUARE FEET\n                          int64
# YEAR BUILT\n                                 int64
# TAX CLASS AT TIME OF SALE\n                  int64
# BUILDING CLASS AT TIME OF SALE\n            object
# ...
